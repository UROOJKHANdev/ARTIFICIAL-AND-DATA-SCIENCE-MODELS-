# %% [markdown]
# <a href="https://colab.research.google.com/github/UROOJKHANdev/ARTIFICIAL-AND-DATA-SCIENCE-MODELS-/blob/main/STATISTICS_AND_PROBABILITY_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("/content/train.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country     City  \
# 9795    SH-19975     Sally Hughsby  Corporate  United States  Chicago
# 9796    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9797    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9798    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
# 9799    CS-12490  Cindy Schnelling  Corporate  United States   Toledo
#
#          State  Postal Code   Region       Product ID         Category  \
# ...

# %%
sample_data = df.sample(n=100)
sample_data
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 5462    5463  CA-2015-146591  19/01/2015  20/01/2015     First Class
# 4707    4708  CA-2018-138149  29/06/2018  30/06/2018     First Class
# 239      240  CA-2017-157749  04/06/2017  09/06/2017    Second Class
# 4565    4566  US-2018-149510  03/12/2018  10/12/2018  Standard Class
# 5444    5445  CA-2016-148712  17/04/2016  23/04/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 6085    6086  US-2017-132577  22/11/2017  27/11/2017  Standard Class
# 9497    9498  CA-2018-118213  05/11/2018  07/11/2018     First Class
# 9770    9771  CA-2017-123533  24/11/2017  30/11/2017  Standard Class
# 5709    5710  US-2016-160857  08/05/2016  15/05/2016  Standard Class
# 9018    9019  CA-2017-161361  26/03/2017  28/03/2017    Second Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
print(df.dtypes)
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
df.shape
# Out:
# (9800, 18)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
print("Mean Sales:", df['Sales'].mean())
# Out:
# Mean Sales: 230.7690594591837

# %%
print("Median Sales:", df['Sales'].median())
# Out:
# Median Sales: 54.489999999999995

# %%
print("Mode Sales:")
print(df['Sales'].mode())
# Out:
# Mode Sales:
# 0    12.96
# Name: Sales, dtype: float64

# %%
df['Sales'].max()
# Out:
# 22638.48

# %%
df['Sales'].min()
# Out:
# 0.444

# %%
sales_range = df['Sales'].max() - df['Sales'].min()

print("Range:", sales_range)
# Out:
# Range: 22638.036

# %%
print("Variance:", df['Sales'].var())
# Out:
# Variance: 392692.5722389889

# %%
print("Standard Deviation:", df['Sales'].std())
# Out:
# Standard Deviation: 626.6518748388047

# %%
print("Skewness:", df['Sales'].skew())
# Out:
# Skewness: 12.983482865034619

# %%
df['Sales'].skew()
df['Sales'].hist()
plt.show()

# %%
print("Kurtosis:", df['Sales'].kurt())
# Out:
# Kurtosis: 304.4450883210413

# %%
df['Postal Code'].mean()
# Out:
# np.float64(55273.322402696904)

# %%
df['Postal Code'].median()
# Out:
# 58103.0

# %%
df['Postal Code'].mode()
# Out:
# 0    10035.0
# Name: Postal Code, dtype: float64

# %%
df['Postal Code'].max()
# Out:
# 99301.0

# %%
df['Postal Code'].min()
# Out:
# 1040.0

# %%
df['Postal Code'].std()
# Out:
# 32041.22341281317

# %%
Postal_Code_range = df['Postal Code'].max() - df['Postal Code'].min()

print("Range:", Postal_Code_range)
# Out:
# Range: 98261.0

# %%
df['Postal Code'].skew()
df['Postal Code'].hist()
plt.show()

# %%
df['City'].mode()
# Out:
# 0    New York City
# Name: City, dtype: object

# %%
df['Category'].mode()
# Out:
# 0    Office Supplies
# Name: Category, dtype: object

# %%
df['Customer Name'].mode()
# Out:
# 0    William Brown
# Name: Customer Name, dtype: object

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)

IQR = Q3 - Q1

print("IQR:", IQR)
# Out:
# IQR: 193.35700000000003

# %%
percentage = (df[df['Category']=="Furniture"].shape[0] / len(df))*100

print("Furniture Percentage:", percentage)
# Out:
# Furniture Percentage: 21.20408163265306

# %%
print("90th Percentile:", df['Sales'].quantile(0.90))
# Out:
# 90th Percentile: 575.932

# %%
prob = len(df[df['Category']=="Furniture"]) / len(df)

print("Probability of Furniture:", prob)
# Out:
# Probability of Furniture: 0.2120408163265306

# %%
prob = len(df[df['Category']=="Office Supplies"]) / len(df)

print(prob)
# Out:
# 0.6029591836734693

# %%
import matplotlib.pyplot as plt

plt.hist(df['Sales'], bins=30)

plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()

# %%
df['Row ID'].skew()
df['Row ID'].hist()
plt.show()

# %%
df['Category'].value_counts(normalize=True)
# Out:
# Category
# Office Supplies    0.602959
# Furniture          0.212041
# Technology         0.185000
# Name: proportion, dtype: float64

# %%
df['Region'].value_counts(normalize=True)
# Out:
# Region
# West       0.320408
# East       0.284184
# Central    0.232347
# South      0.163061
# Name: proportion, dtype: float64

# %%
df['Sub-Category'].value_counts(normalize=True)
# Out:
# Sub-Category
# Binders        0.152245
# Paper          0.136531
# Furnishings    0.095000
# Phones         0.089388
# Storage        0.084898
# Art            0.080102
# Accessories    0.077143
# Chairs         0.061939
# Appliances     0.046837
# Labels         0.036429
# Tables         0.032041
# Envelopes      0.025306
# Bookcases      0.023061
# Fasteners      0.021837
# Supplies       0.018776
# Machines       0.011735
# Copiers        0.006735
# Name: proportion, dtype: float64

# %%
df['Segment'].value_counts(normalize=True)
# Out:
# Segment
# Consumer       0.520510
# Corporate      0.301327
# Home Office    0.178163
# Name: proportion, dtype: float64

# %%
df['Country'].value_counts(normalize=True)
# Out:
# Country
# United States    1.0
# Name: proportion, dtype: float64

# %%
df['Ship Mode'].value_counts(normalize=True)
# Out:
# Ship Mode
# Standard Class    0.597857
# Second Class      0.194082
# First Class       0.153163
# Same Day          0.054898
# Name: proportion, dtype: float64

# %%
print(df[['Sales','Postal Code']].cov())
# Out:
#                      Sales   Postal Code
# Sales        392692.572239 -4.822015e+05
# Postal Code -482201.508080  1.026640e+09

# %%
print(df[['Sales','Postal Code']].corr())
# Out:
#                 Sales  Postal Code
# Sales        1.000000    -0.024067
# Postal Code -0.024067     1.000000

# %%
df["Sales"].hist()
plt.title("Original Sales Distribution")
plt.show()

# %%
sample_data = []

for i in range(1000):
  sample = df["Sales"].sample(30)
  sample_data.append(sample.mean())

plt.hist(sample_data)
# Out:
# (array([303., 431., 179.,  52.,  17.,   8.,   4.,   1.,   3.,   2.]),
#  array([  58.93846667,  166.82901333,  274.71956   ,  382.61010667,
#          490.50065333,  598.3912    ,  706.28174667,  814.17229333,
#          922.06284   , 1029.95338667, 1137.84393333]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np

sample_means = []

for i in range(1000):
    sample = df['Sales'].sample(30)
    sample_means.append(sample.mean())

plt.hist(sample_means, bins=30)

plt.title("Central Limit Theorem")
plt.show()

# %%
from scipy import stats

sample_data = df['Sales'].sample(100)
t_stats, p_value = stats.ttest_1samp(sample, 500)
print("P_Value = ", p_value)
# Out:
# P_Value =  7.267075284947929e-07

# %%
from scipy.stats import ttest_1samp

t_stat, p_value = ttest_1samp(df['Sales'], popmean=200)

print("T Statistic:", t_stat)
print("P Value:", p_value)
# Out:
# T Statistic: 4.8607234822180185
# P Value: 1.1877308679485748e-06

# %%
from scipy.stats import chi2_contingency

sample_data = pd.crosstab(df['Category'], df['Region'])

chi2, p_value , dof, expand = chi2_contingency(sample_data)
print("P_Value = ", p_value)
sample_data
# Out:
# P_Value =  0.6374317692943314
# Region           Central  East  South  West
# Category
# Furniture            470   591    326   691
# Office Supplies     1399  1667    983  1860
# Technology           408   527    289   589

# %%
if p_value < 0.05:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis

# %%
from statsmodels.stats.weightstats import ztest

z_stat, p_value = ztest(df['Sales'], value=200)

print("Z Statistic:", z_stat)
print("P Value:", p_value)
# Out:
# Z Statistic: 4.8607234822180185
# P Value: 1.1695752631395844e-06

# %%
from scipy.stats import chi2_contingency

table = pd.crosstab(df['Category'], df['Region'])

chi2, p, dof, expected = chi2_contingency(table)

print("Chi Square:", chi2)
print("P Value:", p)
# Out:
# Chi Square: 4.290472977284263
# P Value: 0.6374317692943314

# %%
if p < 0.05:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis
